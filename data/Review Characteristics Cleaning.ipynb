# %%
import pandas as pd
import numpy as np

df1 = pd.read_csv('reviews.csv')
df2 = pd.read_csv('characteristics_reviews.csv')

# %%
df1.head()
# Out:
#                                   _id  id  product_id  rating  \
# 0  ObjectId(5f160faa933bf6ba19c590fb)   5           2       3
# 1  ObjectId(5f160faa933bf6ba19c590fc)  13           7       5
# 2  ObjectId(5f160faa933bf6ba19c590fd)   1           1       5
# 3  ObjectId(5f160faa933bf6ba19c590fe)  14           7       1
# 4  ObjectId(5f160faa933bf6ba19c590ff)  15          12       5
#
#                              summary  \
# 0  I'm enjoying wearing these shades
# 1           Ye is good at everything
# 2            This product was great!
# 3                 I don't like Kanye
# 4       Sed repellat quo recusandae.
#
#                                                 body recommend reported  \
# 0                         Comfortable and practical.      true    false
# 1              I mortgaged my house to pay for these      true    false
# 2  I really did or did not like this product base...      true    false
# ...

# %%
df2.head()
# Out:
#                                   _id  id  characteristic_id  review_id  \
# 0  ObjectId(5f16f4d0f0091eec62b7ec7b)  12                  5          6
# 1  ObjectId(5f16f4d0f0091eec62b7ec7c)  13                  5          7
# 2  ObjectId(5f16f4d0f0091eec62b7ec7d)  14                 10          8
# 3  ObjectId(5f16f4d0f0091eec62b7ec7e)   1                  1          1
# 4  ObjectId(5f16f4d0f0091eec62b7ec7f)  15                 11          8
#
#    value            review_mongoid
# 0      3  5f160faa933bf6ba19c59100
# 1      4  5f160faa933bf6ba19c59104
# 2      2  5f160faa933bf6ba19c59103
# 3      4  5f160faa933bf6ba19c590fd
# 4      3  5f160faa933bf6ba19c59103

# %%
df2.drop(['review_mongoid'], inplace=True, axis=1)

# %%
df2.head()
# Out:
#                                   _id  id  characteristic_id  review_id  value
# 0  ObjectId(5f16f4d0f0091eec62b7ec7b)  12                  5          6      3
# 1  ObjectId(5f16f4d0f0091eec62b7ec7c)  13                  5          7      4
# 2  ObjectId(5f16f4d0f0091eec62b7ec7d)  14                 10          8      2
# 3  ObjectId(5f16f4d0f0091eec62b7ec7e)   1                  1          1      4
# 4  ObjectId(5f16f4d0f0091eec62b7ec7f)  15                 11          8      3

# %%
merged = df1.merge(df2, left_on="id", right_on="review_id", how="outer").fillna("")
merged.to_csv("merged.csv", index=False)

# %%
merged = pd.read_csv('merged.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-29-51c88c124a6c> in <module>
# ----> 1 merged = pd.read_csv('merged.csv')
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# ...

# %%
merged.head()

# %%
merged.drop(['id_x','product_id', 'rating', 'summary', 'body', 'recommend', 'reported', 'reviewer_name', 'reviewer_email', 'response', 'helpfulness'], inplace=True, axis=1)

# %%
merged.head()
# Out:
#                                 _id_x                               _id_y  \
# 0  ObjectId(5f160faa933bf6ba19c590fb)  ObjectId(5f16f4d0f0091eec62b7ec93)
# 1  ObjectId(5f160faa933bf6ba19c590fc)  ObjectId(5f16f4d0f0091eec62b7ec9c)
# 2  ObjectId(5f160faa933bf6ba19c590fc)  ObjectId(5f16f4d0f0091eec62b7ec9d)
# 3  ObjectId(5f160faa933bf6ba19c590fc)  ObjectId(5f16f4d0f0091eec62b7ec9e)
# 4  ObjectId(5f160faa933bf6ba19c590fc)  ObjectId(5f16f4d0f0091eec62b7ec9f)
#
#    id_y  characteristic_id  review_id  value
# 0    11                  5          5      5
# 1    34                 22         13      3
# 2    36                 24         13      5
# 3    35                 23         13      4
# 4    37                 25         13      4

# %%
merged.to_csv("characteristics_reviews.csv", index=False)

# %%
merged.head()
# Out:
#                                 _id_x                               _id_y  \
# 0  ObjectId(5f160faa933bf6ba19c590fb)  ObjectId(5f16f4d0f0091eec62b7ec93)
# 1  ObjectId(5f160faa933bf6ba19c590fc)  ObjectId(5f16f4d0f0091eec62b7ec9c)
# 2  ObjectId(5f160faa933bf6ba19c590fc)  ObjectId(5f16f4d0f0091eec62b7ec9d)
# 3  ObjectId(5f160faa933bf6ba19c590fc)  ObjectId(5f16f4d0f0091eec62b7ec9e)
# 4  ObjectId(5f160faa933bf6ba19c590fc)  ObjectId(5f16f4d0f0091eec62b7ec9f)
#
#    id_y  characteristic_id  review_id  value
# 0    11                  5          5      5
# 1    34                 22         13      3
# 2    36                 24         13      5
# 3    35                 23         13      4
# 4    37                 25         13      4

# %%
merged.head()
# Out:
#                                 _id_x                               _id_y  \
# 0  ObjectId(5f160faa933bf6ba19c590fb)  ObjectId(5f16f4d0f0091eec62b7ec93)
# 1  ObjectId(5f160faa933bf6ba19c590fc)  ObjectId(5f16f4d0f0091eec62b7ec9c)
# 2  ObjectId(5f160faa933bf6ba19c590fc)  ObjectId(5f16f4d0f0091eec62b7ec9d)
# 3  ObjectId(5f160faa933bf6ba19c590fc)  ObjectId(5f16f4d0f0091eec62b7ec9e)
# 4  ObjectId(5f160faa933bf6ba19c590fc)  ObjectId(5f16f4d0f0091eec62b7ec9f)
#
#    id_y  characteristic_id  review_id  value
# 0    11                  5          5      5
# 1    34                 22         13      3
# 2    36                 24         13      5
# 3    35                 23         13      4
# 4    37                 25         13      4

# %%
merged.drop(['_id_y'], inplace=True, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-a0339d9d594c> in <module>
# ----> 1 merged.drop(['_id_y'], inplace=True, axis=1)
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...

# %%
merged.head()
# Out:
#                                 _id_x  id_y  characteristic_id  review_id  \
# 0  ObjectId(5f160faa933bf6ba19c590fb)    11                  5          5
# 1  ObjectId(5f160faa933bf6ba19c590fc)    34                 22         13
# 2  ObjectId(5f160faa933bf6ba19c590fc)    36                 24         13
# 3  ObjectId(5f160faa933bf6ba19c590fc)    35                 23         13
# 4  ObjectId(5f160faa933bf6ba19c590fc)    37                 25         13
#
#    value
# 0      5
# 1      3
# 2      5
# 3      4
# 4      4

# %%
merged.to_csv("characteristics_reviews.csv", index=False)

# %%
merged._id_x=merged._id_x.str[8:]

# %%
merged.head()
# Out:
#                         _id_x  id_y  characteristic_id  review_id  value
# 0  (5f160faa933bf6ba19c590fb)    11                  5          5      5
# 1  (5f160faa933bf6ba19c590fc)    34                 22         13      3
# 2  (5f160faa933bf6ba19c590fc)    36                 24         13      5
# 3  (5f160faa933bf6ba19c590fc)    35                 23         13      4
# 4  (5f160faa933bf6ba19c590fc)    37                 25         13      4

# %%
merged._id_x=merged._id_x.str[1:]

# %%
merged.head()
# Out:
#                        _id_x  id_y  characteristic_id  review_id  value
# 0  5f160faa933bf6ba19c590fb)    11                  5          5      5
# 1  5f160faa933bf6ba19c590fc)    34                 22         13      3
# 2  5f160faa933bf6ba19c590fc)    36                 24         13      5
# 3  5f160faa933bf6ba19c590fc)    35                 23         13      4
# 4  5f160faa933bf6ba19c590fc)    37                 25         13      4

# %%
merged._id_x=merged._id_x.str[:-1]

# %%
merged.head()
# Out:
#                       _id_x  id_y  characteristic_id  review_id  value
# 0  5f160faa933bf6ba19c590fb    11                  5          5      5
# 1  5f160faa933bf6ba19c590fc    34                 22         13      3
# 2  5f160faa933bf6ba19c590fc    36                 24         13      5
# 3  5f160faa933bf6ba19c590fc    35                 23         13      4
# 4  5f160faa933bf6ba19c590fc    37                 25         13      4

# %%
merged.to_csv("another_try.csv", index=False)
