# %%
import pandas as pd
import numpy as np

df1 = pd.read_csv('reviews.csv')
df2 = pd.read_csv('characteristics_reviews.csv')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df1.head()
# Out:
#                         _id  id  product_id  rating  \
# 0  5f160faa933bf6ba19c590fb   5           2       3
# 1  5f160faa933bf6ba19c590fc  13           7       5
# 2  5f160faa933bf6ba19c590fd   1           1       5
# 3  5f160faa933bf6ba19c590fe  14           7       1
# 4  5f160faa933bf6ba19c590ff  15          12       5
#
#                              summary  \
# 0  I'm enjoying wearing these shades
# 1           Ye is good at everything
# 2            This product was great!
# 3                 I don't like Kanye
# 4       Sed repellat quo recusandae.
#
#                                                 body recommend reported  \
# 0                         Comfortable and practical.      true    false
# 1              I mortgaged my house to pay for these      true    false
# 2  I really did or did not like this product base...      true    false
# 3  I didn't buy the shoes but I don't like the ma...     false     true
# ...

# %%
df2.head()
# Out:
#                   review_id  product_id  old_id  characteristic_id  \
# 0  5f160faa933bf6ba19c590fb           2      11                  5
# 1  5f160faa933bf6ba19c590fc           7      34                 22
# 2  5f160faa933bf6ba19c590fc           7      35                 23
# 3  5f160faa933bf6ba19c590fc           7      36                 24
# 4  5f160faa933bf6ba19c590fc           7      37                 25
#
#    old_review_id  value
# 0              5      5
# 1             13      3
# 2             13      4
# 3             13      5
# 4             13      4

# %%
df2.loc[df2['review_id'] == '5f160faa933bf6ba19c590fc']
# Out:
#                   review_id  product_id  old_id  characteristic_id  \
# 1  5f160faa933bf6ba19c590fc           7      34                 22
# 2  5f160faa933bf6ba19c590fc           7      35                 23
# 3  5f160faa933bf6ba19c590fc           7      36                 24
# 4  5f160faa933bf6ba19c590fc           7      37                 25
#
#    old_review_id  value
# 1             13      3
# 2             13      4
# 3             13      5
# 4             13      4

# %%
merged = df1.merge(df2, left_on="_id", right_on="review_id", how="left").fillna("")

# %%
merged.head()
# Out:
#                         _id  id  product_id_x  rating  \
# 0  5f160faa933bf6ba19c590fb   5             2       3
# 1  5f160faa933bf6ba19c590fc  13             7       5
# 2  5f160faa933bf6ba19c590fc  13             7       5
# 3  5f160faa933bf6ba19c590fc  13             7       5
# 4  5f160faa933bf6ba19c590fc  13             7       5
#
#                              summary                                   body  \
# 0  I'm enjoying wearing these shades             Comfortable and practical.
# 1           Ye is good at everything  I mortgaged my house to pay for these
# 2           Ye is good at everything  I mortgaged my house to pay for these
# 3           Ye is good at everything  I mortgaged my house to pay for these
# 4           Ye is good at everything  I mortgaged my house to pay for these
#
#   recommend reported   reviewer_name        reviewer_email response  \
# 0      true    false  shortandsweeet  first.last@gmail.com
# ...

# %%
merged.drop(['review_id', 'product_id_y', 'old_id', 'old_review_id'], inplace=True, axis=1)

# %%
merged.head()
# Out:
#                         _id  id  product_id_x  rating  \
# 0  5f160faa933bf6ba19c590fb   5             2       3
# 1  5f160faa933bf6ba19c590fc  13             7       5
# 2  5f160faa933bf6ba19c590fc  13             7       5
# 3  5f160faa933bf6ba19c590fc  13             7       5
# 4  5f160faa933bf6ba19c590fc  13             7       5
#
#                              summary                                   body  \
# 0  I'm enjoying wearing these shades             Comfortable and practical.
# 1           Ye is good at everything  I mortgaged my house to pay for these
# 2           Ye is good at everything  I mortgaged my house to pay for these
# 3           Ye is good at everything  I mortgaged my house to pay for these
# 4           Ye is good at everything  I mortgaged my house to pay for these
#
#   recommend reported   reviewer_name        reviewer_email response  \
# 0      true    false  shortandsweeet  first.last@gmail.com
# ...

# %%
merged["characteristics"] = "{" + merged["characteristic_id"].astype(str) + ": " + merged["value"].astype(str) + "}"

# %%
merged.head()
# Out:
#                         _id  id  product_id_x  rating  \
# 0  5f160faa933bf6ba19c590fb   5             2       3
# 1  5f160faa933bf6ba19c590fc  13             7       5
# 2  5f160faa933bf6ba19c590fc  13             7       5
# 3  5f160faa933bf6ba19c590fc  13             7       5
# 4  5f160faa933bf6ba19c590fc  13             7       5
#
#                              summary                                   body  \
# 0  I'm enjoying wearing these shades             Comfortable and practical.
# 1           Ye is good at everything  I mortgaged my house to pay for these
# 2           Ye is good at everything  I mortgaged my house to pay for these
# 3           Ye is good at everything  I mortgaged my house to pay for these
# 4           Ye is good at everything  I mortgaged my house to pay for these
#
#   recommend reported   reviewer_name        reviewer_email response  \
# 0      true    false  shortandsweeet  first.last@gmail.com
# ...

# %%
merged.drop(['characteristic_id', 'value'], inplace=True, axis=1)

# %%
merged.head()
# Out:
#                         _id  id  product_id_x  rating  \
# 0  5f160faa933bf6ba19c590fb   5             2       3
# 1  5f160faa933bf6ba19c590fc  13             7       5
# 2  5f160faa933bf6ba19c590fc  13             7       5
# 3  5f160faa933bf6ba19c590fc  13             7       5
# 4  5f160faa933bf6ba19c590fc  13             7       5
#
#                              summary                                   body  \
# 0  I'm enjoying wearing these shades             Comfortable and practical.
# 1           Ye is good at everything  I mortgaged my house to pay for these
# 2           Ye is good at everything  I mortgaged my house to pay for these
# 3           Ye is good at everything  I mortgaged my house to pay for these
# 4           Ye is good at everything  I mortgaged my house to pay for these
#
#   recommend reported   reviewer_name        reviewer_email response  \
# 0      true    false  shortandsweeet  first.last@gmail.com
# ...

# %%
merged.groupby(['id'])['characteristics'].apply(lambda x: pd.Series(list(x))).unstack()

# %%
merged.head()
