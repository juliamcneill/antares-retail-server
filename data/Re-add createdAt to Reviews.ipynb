# %%
import pandas as pd
import numpy as np

df1 = pd.read_csv('reviews.csv')
df2 = pd.read_csv('reviews_original.csv')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df1.head()
# Out:
#                                   _id  id  product_id  rating  \
# 0  ObjectId(5f160faa933bf6ba19c590fb)   5           2       3
# 1  ObjectId(5f160faa933bf6ba19c590fc)  13           7       5
# 2  ObjectId(5f160faa933bf6ba19c590fd)   1           1       5
# 3  ObjectId(5f160faa933bf6ba19c590fe)  14           7       1
# 4  ObjectId(5f160faa933bf6ba19c590ff)  15          12       5
#
#                              summary  \
# 0  I'm enjoying wearing these shades
# 1           Ye is good at everything
# 2            This product was great!
# 3                 I don't like Kanye
# 4       Sed repellat quo recusandae.
#
#                                                 body recommend reported  \
# 0                         Comfortable and practical.      true    false
# 1              I mortgaged my house to pay for these      true    false
# 2  I really did or did not like this product base...      true    false
# ...

# %%
df2.head()
# Out:
#    id  product_id  rating   createdAt                            summary  \
# 0   1           1       5  2019-01-01            This product was great!
# 1   2           1       4  2019-01-11               This product was ok!
# 2   3           2       4  2019-06-23          I am liking these glasses
# 3   4           2       4  2019-03-12               They look good on me
# 4   5           2       3  2019-04-14  I'm enjoying wearing these shades
#
#                                                 body recommend reported  \
# 0  I really did or did not like this product base...      true    false
# 1  I really did not like this product solely beca...     false    false
# 2  They are very dark.  But that's good because I...      true    false
# 3                I so stylish and just my aesthetic.      true    false
# 4                         Comfortable and practical.      true    false
#
#         reviewer_name        reviewer_email  \
# 0             funtime  first.last@gmail.com
# ...

# %%
merged = df1.merge(df2[['createdAt', 'id']], left_on="id", right_on="id", how="left").fillna("")

# %%
merged.head()
# Out:
#                                   _id  id  product_id  rating  \
# 0  ObjectId(5f160faa933bf6ba19c590fb)   5           2       3
# 1  ObjectId(5f160faa933bf6ba19c590fc)  13           7       5
# 2  ObjectId(5f160faa933bf6ba19c590fd)   1           1       5
# 3  ObjectId(5f160faa933bf6ba19c590fe)  14           7       1
# 4  ObjectId(5f160faa933bf6ba19c590ff)  15          12       5
#
#                              summary  \
# 0  I'm enjoying wearing these shades
# 1           Ye is good at everything
# 2            This product was great!
# 3                 I don't like Kanye
# 4       Sed repellat quo recusandae.
#
#                                                 body recommend reported  \
# 0                         Comfortable and practical.      true    false
# 1              I mortgaged my house to pay for these      true    false
# 2  I really did or did not like this product base...      true    false
# ...

# %%
merged._id=merged._id.str[9:-1]

# %%
merged = merged.rename(columns={"id":"old_id"})

# %%
merged.to_csv("reviews.csv", index=False)
